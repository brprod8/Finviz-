# %%
from finvizfinance.quote import finvizfinance
import pandas as pd

# %%
from finvizfinance.screener.overview import Overview

foverview = Overview()
filters_dict = {'Index':'Any','Sector':'Any'}
foverview.set_filter(filters_dict=filters_dict)
df = foverview.screener_view().copy()
# Out:
# [Info] loading page [##############################] 430/430

# %%
df
# Out:
#      Ticker                           Company              Sector  \
# 0         A        Agilent Technologies, Inc.          Healthcare
# 1        AA                 Alcoa Corporation     Basic Materials
# 2      AAAU   Goldman Sachs Physical Gold ETF           Financial
# 3       AAC      Ares Acquisition Corporation           Financial
# 4      AACG             ATA Creativity Global  Consumer Defensive
# ...     ...                               ...                 ...
# 8585    ZWS  Zurn Water Solutions Corporation         Industrials
# 8586     ZY                     Zymergen Inc.     Basic Materials
# 8587   ZYME                    Zymeworks Inc.          Healthcare
# 8588   ZYNE     Zynerba Pharmaceuticals, Inc.          Healthcare
# 8589   ZYXI                       Zynex, Inc.          Healthcare
#
#                                       Industry Country    Market Cap    P/E  \
# 0                       Diagnostics & Research     USA  3.856000e+10  30.98
# ...

# %%
Sectors = ['Consumer Cyclical']
# 'Healthcare','Consumer Cyclical','Financial','Communication Services','Energy','Industrials','Basic Materials','Real Estate','Consumer Defensive','Utilities']

class Calculator:
    def __init__(self)
     self.new_data = self.create_df()
    
    
    def calc(sectors):
        data = df[df.Sector == sectors]
    
        calc = data[['Market Cap']].sum()[0]
        empty = pd.DataFrame()
        collect= {sectors:[calc]}
        create = pd.DataFrame(collect)
        empty[sectors] = create[sectors]
        return empty

    
    
    

    
    

calc('Consumer Cyclical')    

calc('Communication Services')
    

    
# a = df[df.Sector == 'Healthcare'][['Market Cap']].sum()[0]

# collect = {'Healthcare':[a]}

# # empty = pd.DataFrame()

# b = pd.DataFrame(collect)



# b



 

# empty['tech'] = b['tech'] 

# empty
# Out:
#    Communication Services
# 0            6.475271e+12

# %%
Group_Sector_market = df[['Sector',]]

# %%
a = Group_Sector_market.drop_duplicates(subset=['Sector'])

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

from finvizfinance.group.performance import Performance as OV

view = OV()

view.screener_view().sort_values(['Volume'],ascending=False)
# Out:
#                       Name Perf Week  Perf Month  Perf Quart  Perf Half  \
# 9               Technology    -1.23%       -0.02       -0.06      -0.22
# 6               Healthcare    -3.06%       -0.01       -0.02      -0.07
# 2        Consumer Cyclical    -0.17%       -0.03       -0.04      -0.23
# 5                Financial    -1.05%        0.01       -0.00      -0.06
# 1   Communication Services     0.86%       -0.00       -0.07      -0.21
# 4                   Energy     1.20%        0.09        0.14       0.48
# 7              Industrials     0.80%        0.00       -0.01      -0.08
# 0          Basic Materials    -0.07%        0.03        0.01       0.09
# 8              Real Estate    -0.49%       -0.02       -0.04      -0.10
# 3       Consumer Defensive    -1.42%       -0.04       -0.01      -0.00
# 10               Utilities    -0.85%        0.04        0.04       0.10
#
#     Perf Year  Perf YTD  Recom    Avg Volume  Rel Volume  Change        Volume
# ...
